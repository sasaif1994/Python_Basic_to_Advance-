# %%
import plotly
import os
import pandas as pd
import numpy as np
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
os.chdir(r"D:\Imarticus\Machine Learning")
lcn=pd.read_csv("LungCapData.csv")
lcn
# Out:
#      LungCap  Age  Height Smoke  Gender Caesarean
# 0      6.475    6    62.1    no    male        no
# 1     10.125   18    74.7   yes  female        no
# 2      9.550   16    69.7    no  female       yes
# 3     11.125   14    71.0    no    male        no
# 4      4.800    5    56.9    no    male        no
# ..       ...  ...     ...   ...     ...       ...
# 720    5.725    9    56.0    no  female        no
# 721    9.050   18    72.0   yes    male       yes
# 722    3.850   11    60.5   yes  female        no
# 723    9.825   15    64.9    no  female        no
# 724    7.100   10    67.7    no    male        no
#
# [725 rows x 6 columns]

# %%
lcn.iplot()
# Out:
# <div>                            <div id="b94c0c37-fddc-4de2-9eab-38244ae5db86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
lcn.iplot(kind="scatter",x="Age",y="LungCap",mode="markers")
# Out:
# <div>                            <div id="348b71fe-9e44-4abc-ad8d-59ec322e6215" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
lcn.iplot(kind="bar",x="Age",y="Gender",mode="LungCap")
# Out:
# <div>                            <div id="20a128ab-c4ce-4733-b39a-c9c80c23203f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
lcn.sum().iplot(kind="bar")
# Out:
# <div>                            <div id="dbeffc78-8837-4b07-bb0b-124be12421a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
lcn.iplot(kind="box")
# Out:
# <div>                            <div id="9ac67cf2-72e7-4216-9d11-bf83bcb25c46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
lcn.LungCap.iplot(kind="hist",color="Blue",title="Lung Capacity",yTitle="count",xTitle="Intervals")
# Out:
# <div>                            <div id="69a256fa-638a-4690-8f4d-30d755b164cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
lcn.iplot(kind="hist")
# Out:
# <div>                            <div id="72dc7ae4-df7c-4218-80b0-91b25151c1a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
count_gdp=pd.DataFrame({'GDP':(19.4,11.8,4.8,3.4,2.5,2.4),'countries':('US','CHINA','JAPAN','GERM','UK','INDIA')})
count_gdp
# Out:
#     GDP countries
# 0  19.4        US
# 1  11.8     CHINA
# 2   4.8     JAPAN
# 3   3.4      GERM
# 4   2.5        UK
# 5   2.4     INDIA

# %%
import plotly.express

# %%
plotly.express.pie(count_gdp,names='countries',values='GDP',title='GDP of top 6 economies')
# Out:
# <div>                            <div id="b4781b37-59fd-494a-8351-59e3059c4afb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4781b37-59fd-494a-8351-59e3059c4afb")) {                    Plotly.newPlot(                        "b4781b37-59fd-494a-8351-59e3059c4afb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"countries=%{label}<br>GDP=%{value}<extra></extra>","labels":["US","CHINA","JAPAN","GERM","UK","INDIA"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[19.4,11.8,4.8,3.4,2.5,2.4]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmod
# ...

# %%
plotly.express.pie(count_gdp,names='countries',values='GDP',title='GDP of top 6 economies',hole=.6)
# Out:
# <div>                            <div id="9b7ab362-531e-43ec-8e97-84969325786a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b7ab362-531e-43ec-8e97-84969325786a")) {                    Plotly.newPlot(                        "9b7ab362-531e-43ec-8e97-84969325786a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"countries=%{label}<br>GDP=%{value}<extra></extra>","labels":["US","CHINA","JAPAN","GERM","UK","INDIA"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[19.4,11.8,4.8,3.4,2.5,2.4]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern
# ...

# %%
plotly.express.scatter(lcn,x="Age",y="LungCap",hover_data=["Height"],color='Gender')
# Out:
# <div>                            <div id="31e758a3-5661-43a9-a0b1-e039b60718be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31e758a3-5661-43a9-a0b1-e039b60718be")) {                    Plotly.newPlot(                        "31e758a3-5661-43a9-a0b1-e039b60718be",                        [{"customdata":[[62.1],[71.0],[56.9],[63.3],[70.4],[70.5],[59.2],[76.4],[71.7],[57.5],[61.2],[63.5],[59.2],[56.1],[57.3],[72.4],[68.0],[61.3],[65.6],[64.7],[69.3],[65.6],[67.8],[65.5],[52.7],[63.6],[77.7],[67.7],[49.3],[61.7],[74.9],[61.6],[66.4],[74.1],[65.3],[61.4],[79.6],[52.9],[65.6],[79.1],[65.4],[68.2],[65.1],[68.0],[72.4],[66.6],[69.8],[69.3],[72.2],[78.4],[75.5],[63.9],[69.4],[72.8],[71.1],[64.7],[74.9],[57.0],[66.2],[66.9],[75.5],[64.8],[63.2],[52.1],[70.
# ...

# %% [markdown]
# <h2><font color ='Blue'>TASK</font></h2><h4>Build 3D visualization </h4>
